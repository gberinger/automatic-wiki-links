# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
results_df = pd.read_csv('results_3.csv')

# %%
plt.scatter(results_df['epoch'], results_df['cos_dist'])
plt.xlabel('Epoch')
plt.ylabel('Avg cos dist')
plt.title('Avg cos dist, context (context=3)')
plt.savefig('plot_3.png')
plt.show()

# %%
contexts = range(1, 11)
for c in contexts:
    results_df = pd.read_csv('results_{}.csv'.format(c))
    plt.plot(results_df['epoch'], results_df['top1_acc'], 'bo-')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Top-1 accuracy, context={}, alpha=0.15'.format(c))
    plt.savefig('top1_acc_{}.png'.format(c))
    plt.show()
    print('Context={}, max_acc={}'.format(c, results_df['top1_acc'].max()))
# Out:
# Context=1, max_acc=0.6333333333333333
# Context=2, max_acc=0.6666666666666666
# Context=3, max_acc=0.725
# Context=4, max_acc=0.7416666666666667
# Context=5, max_acc=0.7166666666666667
# Context=6, max_acc=0.675
# Context=7, max_acc=0.6833333333333333
# Context=8, max_acc=0.7166666666666667
# Context=9, max_acc=0.7083333333333334
# Context=10, max_acc=0.7

# %%
results_df = pd.read_csv('results_4_cos_dist.csv')
plt.plot(results_df['epoch'], results_df['top1_acc'], 'bo-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Top-1 accuracy, context=4, alpha=cos_dist')
plt.savefig('top1_acc_4_cos_dist.png')
plt.show()
print('Context=4, max_acc={}'.format(results_df['top1_acc'].max()))
# Out:
# Context=4, max_acc=0.7333333333333333
